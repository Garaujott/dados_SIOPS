# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Guilherme\\OneDrive\\MEI\\Projetos\\CONASEMS_SIOPS'

# %%
arquivo = 'data\\2018\\Despesa\\1 - Recursos Ordinários - Fonte Livre\\301_1_Atenção Basica.xlsx'

# %%
arquivo[0:56]
# Out:
# 'data\\2018\\Despesa\\1 - Recursos Ordinários - Fonte Livre\\'

# %%
dados = pd.read_excel(arquivo)
dados.head()
# Out:
#    COD. ESTADO   UF    ESTADO  Dotação Inicial       Unnamed: 4  \
# 0          NaN  NaN       NaN  3.0.00.00.00.00  3.1.00.00.00.00
# 1         12.0   AC      Acre              NaN              NaN
# 2         27.0   AL   Alagoas              NaN              NaN
# 3         16.0   AP    Amapá               NaN              NaN
# 4         13.0   AM  Amazonas              NaN              NaN
#
#         Unnamed: 5       Unnamed: 6       Unnamed: 7       Unnamed: 8  \
# 0  3.1.30.00.00.00  3.1.35.00.00.00  3.1.36.00.00.00  3.1.45.00.00.00
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#         Unnamed: 9  ...    Unnamed: 2338    Unnamed: 2339    Unnamed: 2340  \
# 0  3.1.46.00.00.00  ...  4.6.74.00.00.00  4.6.90.00.00.00  4.6.99.00.00.00
# 1              NaN  ...              NaN              NaN              NaN
# 2              NaN  ...              NaN              NaN              NaN
# 3              NaN  ...              NaN              NaN              NaN
# 4              NaN  ...              NaN              NaN              NaN
#
#   Unnamed: 2341 Unnamed: 2342 Unnamed: 2343 Unnamed: 2344 Unnamed: 2345  \
# 0    ACDO000001    ACDO000002    ACDO000003    ACDO000004    ACDO000005
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   Unnamed: 2346 Unnamed: 2347
# 0    ACDO000006    ACDO000007
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#
# [5 rows x 2348 columns]

# %%
anos = ['2018', '2019', '2020']

pastas = ['1 - Recursos Ordinários - Fonte Livre', 
          '2 - Receitas de Impostos e Transferencias de Impostos', 
          '3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal', 
          '4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual', 
          '5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde', 
          '6 - Operações de Crédito Vinculadas à Saúde', 
          '7 - Royalties de Petróleo Vinculadas à Saúde', 
          '8 - Outros Recursos Vinculados à Saúde']

arquivos = ['301 - Atenção Basica', '302 - Assistência Hospitalar Ambulatorial',
            '303 - Suporte Profilático Terapêutico', '304 - Vigilância Sanitária',
            '305 - Vigilância Epidemiológica', '305 - Vigilância Epidemiológica',
            'Administrativas', 'Informações Complementares']


caminho_import_arq = []
caminho_import_pastas = []
caminho_import_anos = []
caminho_export = 


# arquivo = ['data\\2018\\Despesa']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\GUILHE~1\AppData\Local\Temp/ipykernel_13748/696930038.py in <module>
#      21
#      22 for a in anos:
# ---> 23     caminho_import_anos.append('data\\' + a + '\\Despesa\\' + caminho_import_pastas[i])
#      24     for p, i in pastas:
#      25         caminho_import_pastas.append(p + caminho_import_arq[i])
#
# TypeError: list indices must be integers or slices, not str

# %%
anos = ['2018', '2019', '2020']

pastas = ['1 - Recursos Ordinários - Fonte Livre', 
          '2 - Receitas de Impostos e Transferencias de Impostos', 
          '3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal', 
          '4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual', 
          '5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde', 
          '6 - Operações de Crédito Vinculadas à Saúde', 
          '7 - Royalties de Petróleo Vinculadas à Saúde', 
          '8 - Outros Recursos Vinculados à Saúde']

arquivos = ['301 - Atenção Basica', '302 - Assistência Hospitalar Ambulatorial',
            '303 - Suporte Profilático Terapêutico', '304 - Vigilância Sanitária',
            '305 - Vigilância Epidemiológica', '306 - Alimentação e Nutrição', 
            'Administrativas', 'Informações Complementares']

caminho_import = []

for i in range(len(anos)):
    for j in range(len(pastas)):
        for k in range(len(arquivos)):
            caminho_import.append('\\data\\' + anos[i] + '\\Despesa\\' + pastas[j] + '\\' + arquivos[k] + '.xlsx')
            
caminho_export = []

for i in range(len(anos)):
    for j in range(len(pastas)):
        for k in range(len(arquivos)):
            caminho_export.append('\\data\\' + anos[i] + '\\csv' + '\\Despesa\\' + pastas[j] + '\\' + arquivos[k] + '.csv')

pastas_export = []        
for i in range(len(anos)):
    for j in range(len(pastas)):
        for k in range(len(arquivos)):
            pastas_export.append('\\data\\' + anos[i] + '\\csv' + '\\Despesa\\' + pastas[j])


for i in pastas_export:
    os.makedirs(os.getcwd() + i, mode = 0o666, exist_ok = True)

# %%
def imp_exp_siops_despesas(arquivo_import, arquivo_export):
    dados = pd.read_excel(os.getcwd() + arquivo_import)
    dados.set_index(keys = 'UF', drop = False, inplace = True)
    
    cols_ident = dados.iloc[1:, 0:3]
    cols_ident.columns = ['COD. ESTADO', 'UF', 'ESTADO']
    
    colunas = ['COD. ESTADO', 'UF', 'ESTADO'] + ['c' + x for x in dados.iloc[0, 3:338].tolist()]
    colunas_valores = ['c' + x for x in dados.iloc[0, 3:338].tolist()]
    
    lst_cat_var = ['dot_inicial', 'dot_atualizada', 'despesas_empenhadas', 
                   'despesas_liquidadas', 'despesas_pagas', 'restos_a_pagar', 
                   'despesas_orcadas']
    lst_categorias = ['Dotação Inicial', 'Dotação Atualizada', 'Despesas Empenhadas', 
                      'Despesas Liquidadas', 'Despesas Pagas', 'Inscritas em Restos a Pagar não Processados', 
                      'Despesas Orçadas']
    lst_slices = [dados.iloc[1:, 3:338], dados.iloc[1:, 338:673], dados.iloc[1:, 673:1008], 
                  dados.iloc[1:, 1008:1343], dados.iloc[1:, 1343:1678], dados.iloc[1:, 1678:2013],
                  dados.iloc[1:, 2013:]]
        
    dados_final = pd.DataFrame()
    
    for k, i, j in zip(lst_cat_var, lst_categorias, lst_slices):
        k = []
        k = pd.concat(objs = [cols_ident, j], axis = 1)
        k.columns = colunas
        k['Categoria'] = i
        cols = ['Categoria'] + colunas
        k = k[cols]
        k['COD. ESTADO'] = k['COD. ESTADO'].astype(int).astype(str)
        k[colunas_valores] = k[colunas_valores].astype(float)
        k.reset_index(drop = True, inplace = True)
        dados_final = pd.concat([dados_final, k], axis = 0)
            
    dados_final.to_csv(path_or_buf = os.getcwd() + arquivo_export, index = False, encoding = 'iso-8859-1')
    print(f'{arquivo_export} exportado')

# %%
for i in range(len(caminho_import)):
    imp_exp_siops_despesas(caminho_import[i], caminho_export[i])
# Out:
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\Administrativas.csv exportado
# \data\2018\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\Informações Complementares.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\Administrativas.csv exportado
# \data\2018\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\Informações Complementares.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\Administrativas.csv exportado
# \data\2018\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\Informações Complementares.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\Administrativas.csv exportado
# \data\2018\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\Informações Complementares.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\Administrativas.csv exportado
# \data\2018\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\Informações Complementares.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\Administrativas.csv exportado
# \data\2018\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\Informações Complementares.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\Administrativas.csv exportado
# \data\2018\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\Informações Complementares.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\301 - Atenção Basica.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\Administrativas.csv exportado
# \data\2018\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\Administrativas.csv exportado
# \data\2019\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\Administrativas.csv exportado
# \data\2019\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\Administrativas.csv exportado
# \data\2019\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\Administrativas.csv exportado
# \data\2019\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\Administrativas.csv exportado
# \data\2019\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\Administrativas.csv exportado
# \data\2019\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\Administrativas.csv exportado
# \data\2019\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\Informações Complementares.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\301 - Atenção Basica.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\Administrativas.csv exportado
# \data\2019\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\Administrativas.csv exportado
# \data\2020\csv\Despesa\1 - Recursos Ordinários - Fonte Livre\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\Administrativas.csv exportado
# \data\2020\csv\Despesa\2 - Receitas de Impostos e Transferencias de Impostos\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\Administrativas.csv exportado
# \data\2020\csv\Despesa\3 - Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Federal\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\Administrativas.csv exportado
# \data\2020\csv\Despesa\4 -Transferência Fundo a Fundo de Recursos do SUS Provenientes do Governo Estadual\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\Administrativas.csv exportado
# \data\2020\csv\Despesa\5 - Transferência de Convênios ou de Contratos de Repasse Vinculados à Saúde\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\Administrativas.csv exportado
# \data\2020\csv\Despesa\6 - Operações de Crédito Vinculadas à Saúde\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\Administrativas.csv exportado
# \data\2020\csv\Despesa\7 - Royalties de Petróleo Vinculadas à Saúde\Informações Complementares.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\301 - Atenção Basica.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\302 - Assistência Hospitalar Ambulatorial.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\303 - Suporte Profilático Terapêutico.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\304 - Vigilância Sanitária.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\305 - Vigilância Epidemiológica.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\306 - Alimentação e Nutrição.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\Administrativas.csv exportado
# \data\2020\csv\Despesa\8 - Outros Recursos Vinculados à Saúde\Informações Complementares.csv exportado

# %%
# def imp_exp_siops_despesas_modo(arquivo, modo_saida):
#     if modo_saida = 'separada':
                
#         dados = pd.read_excel(arquivo)
#         dados.set_index(keys = 'UF', drop = False, inplace = True)
    
#         cols_ident = dados.iloc[1:, 0:3]
#         cols_ident.columns = ['COD. ESTADO', 'UF', 'ESTADO']
    
#         colunas = ['COD. ESTADO', 'UF', 'ESTADO'] + ['c' + x for x in dados.iloc[0, 3:338].tolist()]
#         colunas_valores = ['c' + x for x in dados.iloc[0, 3:338].tolist()]
    
#         lst_cat_var = ['dot_inicial', 'dot_atualizada', 'despesas_empenhadas', 
#                       'despesas_liquidadas', 'despesas_pagas', 'restos_a_pagar', 
#                       'despesas_orcadas']
#         lst_categorias = ['Dotação Inicial', 'Dotação Atualizada', 'Despesas Empenhadas', 
#                       'Despesas Liquidadas', 'Despesas Pagas', 'Inscritas em Restos a Pagar não Processados', 
#                       'Despesas Orçadas']
#         lst_slices = [dados.iloc[1:, 3:338], dados.iloc[1:, 338:673], dados.iloc[1:, 673:1008], 
#                   dados.iloc[1:, 1008:1343], dados.iloc[1:, 1343:1678], dados.iloc[1:, 1678:2013],
#                   dados.iloc[1:, 2013:]]
        
#         dados_final = pd.DataFrame()
#         for k, i, j in zip(lst_cat_var, lst_categorias, lst_slices):
#             dados_k = []
#             dados_k = pd.concat(objs = [cols_ident, j], axis = 1)
#             dados_k.columns = colunas
#             dados_k['Categoria'] = i
#             cols = ['Categoria'] + colunas
#             dados_k = dados_k[cols]
#             dados_k['COD. ESTADO'] = dados_k['COD. ESTADO'].astype(int).astype(str)
#             dados_k[colunas_valores] = dados_k[colunas_valores].astype(float)
#             dados_k.reset_index(drop = True, inplace = True)
#             dados_k.to_csv(path_or_buf = arquivo + '\\' + 'k' + '.csv', index = False, encoding = 'iso-8859-1')
        
#     if modo_saida = 'empilhada':
#         dados = pd.read_excel(arquivo)
#         dados.set_index(keys = 'UF', drop = False, inplace = True)
    
#         cols_ident = dados.iloc[1:, 0:3]
#         cols_ident.columns = ['COD. ESTADO', 'UF', 'ESTADO']
    
#         colunas = ['COD. ESTADO', 'UF', 'ESTADO'] + ['c' + x for x in dados.iloc[0, 3:338].tolist()]
#         colunas_valores = ['c' + x for x in dados.iloc[0, 3:338].tolist()]
    
#         lst_cat_var = ['dot_inicial', 'dot_atualizada', 'despesas_empenhadas', 
#                       'despesas_liquidadas', 'despesas_pagas', 'restos_a_pagar', 
#                       'despesas_orcadas']
#         lst_categorias = ['Dotação Inicial', 'Dotação Atualizada', 'Despesas Empenhadas', 
#                       'Despesas Liquidadas', 'Despesas Pagas', 'Inscritas em Restos a Pagar não Processados', 
#                       'Despesas Orçadas']
#         lst_slices = [dados.iloc[1:, 3:338], dados.iloc[1:, 338:673], dados.iloc[1:, 673:1008], 
#                   dados.iloc[1:, 1008:1343], dados.iloc[1:, 1343:1678], dados.iloc[1:, 1678:2013],
#                   dados.iloc[1:, 2013:]]
        
#         dados_final = pd.DataFrame()
#         for k, i, j in zip(lst_cat_var, lst_categorias, lst_slices):
#             dados_k = []
#             dados_k = pd.concat(objs = [cols_ident, j], axis = 1)
#             dados_k.columns = colunas
#             dados_k['Categoria'] = i
#             cols = ['Categoria'] + colunas
#             dados_k = dados_k[cols]
#             dados_k['COD. ESTADO'] = dados_k['COD. ESTADO'].astype(int).astype(str)
#             dados_k[colunas_valores] = dados_k[colunas_valores].astype(float)
#             dados_k.reset_index(drop = True, inplace = True)
#             dados_final = pd.concat([dados_final, dados_k], axis = 0)
            
#         dados_final.to_csv(path_or_buf = os.getcwd() + '\\' + 'test' + '.csv', index = False, encoding = 'iso-8859-1')
# Out:
#   File "C:\Users\GUILHE~1\AppData\Local\Temp/ipykernel_13748/4254649900.py", line 1
#     def imp_exp_siops_despesas(arquivo, modo_saida, pasta_saida = arquivo[0:56])
#                                                                                 ^
# SyntaxError: invalid syntax

# %%
        dados = pd.read_excel(arquivo)
        dados.set_index(keys = 'UF', drop = False, inplace = True)
    
        cols_ident = dados.iloc[1:, 0:3]
        cols_ident.columns = ['COD. ESTADO', 'UF', 'ESTADO']
    
        colunas = ['COD. ESTADO', 'UF', 'ESTADO'] + ['c' + x for x in dados.iloc[0, 3:338].tolist()]
        colunas_valores = ['c' + x for x in dados.iloc[0, 3:338].tolist()]
    
        lst_cat_var = ['dot_inicial', 'dot_atualizada', 'despesas_empenhadas', 
                      'despesas_liquidadas', 'despesas_pagas', 'restos_a_pagar', 
                      'despesas_orcadas']
        lst_categorias = ['Dotação Inicial', 'Dotação Atualizada', 'Despesas Empenhadas', 
                      'Despesas Liquidadas', 'Despesas Pagas', 'Inscritas em Restos a Pagar não Processados', 
                      'Despesas Orçadas']
        lst_slices = [dados.iloc[1:, 3:338], dados.iloc[1:, 338:673], dados.iloc[1:, 673:1008], 
                  dados.iloc[1:, 1008:1343], dados.iloc[1:, 1343:1678], dados.iloc[1:, 1678:2013],
                  dados.iloc[1:, 2013:]]
        
        dados_final = pd.DataFrame()
        for k, i, j in zip(lst_cat_var, lst_categorias, lst_slices):
            dados_k = []
            dados_k = pd.concat(objs = [cols_ident, j], axis = 1)
            dados_k.columns = colunas
            dados_k['Categoria'] = i
            cols = ['Categoria'] + colunas
            dados_k = dados_k[cols]
            dados_k['COD. ESTADO'] = dados_k['COD. ESTADO'].astype(int).astype(str)
            dados_k[colunas_valores] = dados_k[colunas_valores].astype(float)
            dados_k.reset_index(drop = True, inplace = True)
            dados_final = pd.concat([dados_final, dados_k], axis = 0)
            
        dados_final.to_csv(path_or_buf = os.getcwd() + '\\' + 'test' + '.csv', index = False, encoding = 'iso-8859-1')
